# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta
import json
import os
import pandas as pd
import requests

# %%
url = "https://data.cityofchicago.org/resource/wrvz-psew.json?trip_id=00000019ef3c0b419a9e6b1843b83530b79627a4"

headers = {"X-APP-Token": os.environ.get("CHICHAGO_API_TOKEN")}
response = requests.get(url, headers)

data = response.json()

# %%
data
# Out:
# [{'trip_id': '00000019ef3c0b419a9e6b1843b83530b79627a4',
#   'taxi_id': 'bda916a4fa3043f7e827751d9d8cada1239d574beb206d846e1d7d425b658d56aa23393b6866d3a19f9dca6c32d3a8642f14361c5d58dccebd42e398fee18e94',
#   'trip_start_timestamp': '2023-12-11T16:15:00.000',
#   'trip_end_timestamp': '2023-12-11T17:00:00.000',
#   'trip_seconds': '2572',
#   'trip_miles': '17.56',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031081700',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '43.75',
#   'tips': '12.06',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '60.31',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.892042136',
# ...

# %%
url = f"https://data.cityofchicago.org/resource/ajtu-isnz.json?$where=trip_start_timestamp >= '2024-03-05T00:00:00' AND trip_start_timestamp <= '2024-03-05T23:59:59'&$limit=30000"

headers = {"X-APP-Token": os.environ.get("CHICHAGO_API_TOKEN")}
response = requests.get(url, headers)

data = response.json()

# %%
# Extract T-8 months data

current_datetime = datetime.now() - relativedelta(months=2)

formatted_datetime = current_datetime.strftime("%Y-%m-%d")


url = f"https://data.cityofchicago.org/resource/ajtu-isnz.json?$where=trip_start_timestamp >= '{formatted_datetime}T00:00:00' AND trip_start_timestamp <= '{formatted_datetime}T23:59:59'&$limit=30000"

headers = {"X-APP-Token": os.environ.get("CHICHAGO_API_TOKEN")}

response = requests.get(url, headers)

data = response.json()

# %%
data
# Out:
# [{'trip_id': '00c6d0cc3d95795a2b9cb3fcbb3afa8eed897ac7',
#   'taxi_id': '3ae83cc261cea27eafc3d9b18bbc93100c03762e8b6971ee60ec7c34e975fde969dfaad88186def33c7205ef5aa98f5fc01f8419f70f7f30ab5b8af02663a2e3',
#   'trip_start_timestamp': '2024-03-15T23:45:00.000',
#   'trip_end_timestamp': '2024-03-16T00:15:00.000',
#   'trip_seconds': '1680',
#   'trip_miles': '1',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031320100',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '32',
#   'fare': '42.25',
#   'tips': '9.55',
#   'tolls': '0',
#   'extras': '5',
#   'trip_total': '56.8',
#   'payment_type': 'Credit Card',
#   'company': 'Taxi Affiliation Services',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.884987192',
# ...
